# %%
import requests
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import time
import datetime

# %%
spotipy_client_id = 'CLIENTID'
spotipy_client_secret = 'SECRETID'
spotipy_redirect_uri = 'URI'
scope = 'user-top-read'

# %%
sp = spotipy.Spotify(auth_manager = SpotifyOAuth(client_id = spotipy_client_id, 
                                                client_secret = spotipy_client_secret, 
                                                redirect_uri = spotipy_redirect_uri,
                                                scope = scope))

# %%
top_tracks_short = sp.current_user_top_tracks(limit=10, offset=0, time_range = 'short_term')

# %%
top_tracks_short
# Out:
# {'items': [{'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7blXVKBSxdFZsIqlhdViKc'},
#       'href': 'https://api.spotify.com/v1/artists/7blXVKBSxdFZsIqlhdViKc',
#       'id': '7blXVKBSxdFZsIqlhdViKc',
#       'name': 'Valley',
#       'type': 'artist',
#       'uri': 'spotify:artist:7blXVKBSxdFZsIqlhdViKc'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3RJi4CGEm5KVAdPxl2fWWa'},
#     'href': 'https://api.spotify.com/v1/albums/3RJi4CGEm5KVAdPxl2fWWa',
#     'id': '3RJi4CGEm5KVAdPxl2fWWa',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273634e1fb57aea679660033b25',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02634e1fb57aea679660033b25',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851634e1fb57aea679660033b25',
#       'width': 64}],
#     'name': 'The After Party',
#     'release_date': '2022-01-12',
#     'release_date_precision': 'day',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:3RJi4CGEm5KVAdPxl2fWWa'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7blXVKBSxdFZsIqlhdViKc'},
#      'href': 'https://api.spotify.com/v1/artists/7blXVKBSxdFZsIqlhdViKc',
#      'id': '7blXVKBSxdFZsIqlhdViKc',
#      'name': 'Valley',
#      'type': 'artist',
#      'uri': 'spotify:artist:7blXVKBSxdFZsIqlhdViKc'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 237230,
#    'explicit': True,
#    'external_ids': {'isrc': 'CAUM72100439'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/697MdxMbVWn1Ajbw8iaPv5'},
#    'href': 'https://api.spotify.com/v1/tracks/697MdxMbVWn1Ajbw8iaPv5',
#    'id': '697MdxMbVWn1Ajbw8iaPv5',
#    'is_local': False,
#    'name': 'Last Birthday',
#    'popularity': 60,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2e5c1d6dfb844d9823c5efb5f2ed32d56d621343?cid=07d38296a179477cb2c5422a972d33de',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:697MdxMbVWn1Ajbw8iaPv5'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7blXVKBSxdFZsIqlhdViKc'},
#       'href': 'https://api.spotify.com/v1/artists/7blXVKBSxdFZsIqlhdViKc',
#       'id': '7blXVKBSxdFZsIqlhdViKc',
#       'name': 'Valley',
#       'type': 'artist',
#       'uri': 'spotify:artist:7blXVKBSxdFZsIqlhdViKc'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3RJi4CGEm5KVAdPxl2fWWa'},
#     'href': 'https://api.spotify.com/v1/albums/3RJi4CGEm5KVAdPxl2fWWa',
#     'id': '3RJi4CGEm5KVAdPxl2fWWa',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273634e1fb57aea679660033b25',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02634e1fb57aea679660033b25',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851634e1fb57aea679660033b25',
#       'width': 64}],
#     'name': 'The After Party',
#     'release_date': '2022-01-12',
#     'release_date_precision': 'day',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:3RJi4CGEm5KVAdPxl2fWWa'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7blXVKBSxdFZsIqlhdViKc'},
#      'href': 'https://api.spotify.com/v1/artists/7blXVKBSxdFZsIqlhdViKc',
#      'id': '7blXVKBSxdFZsIqlhdViKc',
#      'name': 'Valley',
#      'type': 'artist',
#      'uri': 'spotify:artist:7blXVKBSxdFZsIqlhdViKc'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 240083,
#    'explicit': True,
#    'external_ids': {'isrc': 'CAUM72100374'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7q0ez7c8f92Rwpl6nVw5M6'},
#    'href': 'https://api.spotify.com/v1/tracks/7q0ez7c8f92Rwpl6nVw5M6',
#    'id': '7q0ez7c8f92Rwpl6nVw5M6',
#    'is_local': False,
#    'name': '7 Stories',
#    'popularity': 51,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6e29f8c31463716c409a9c713d129e02e4af0ece?cid=07d38296a179477cb2c5422a972d33de',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:7q0ez7c8f92Rwpl6nVw5M6'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qDMrpZHtZEtVl5i1l7hP3'},
#       'href': 'https://api.spotify.com/v1/artists/3qDMrpZHtZEtVl5i1l7hP3',
#       'id': '3qDMrpZHtZEtVl5i1l7hP3',
#       'name': 'Nightly',
#       'type': 'artist',
#       'uri': 'spotify:artist:3qDMrpZHtZEtVl5i1l7hP3'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4DHc6jdGV40ZcJeDzPpAGF'},
#     'href': 'https://api.spotify.com/v1/albums/4DHc6jdGV40ZcJeDzPpAGF',
#     'id': '4DHc6jdGV40ZcJeDzPpAGF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f3fa268c33fa25670adf4e78',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f3fa268c33fa25670adf4e78',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f3fa268c33fa25670adf4e78',
#       'width': 64}],
#     'name': 'Lose My Number',
#     'release_date': '2021-10-28',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4DHc6jdGV40ZcJeDzPpAGF'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qDMrpZHtZEtVl5i1l7hP3'},
#      'href': 'https://api.spotify.com/v1/artists/3qDMrpZHtZEtVl5i1l7hP3',
#      'id': '3qDMrpZHtZEtVl5i1l7hP3',
#      'name': 'Nightly',
#      'type': 'artist',
#      'uri': 'spotify:artist:3qDMrpZHtZEtVl5i1l7hP3'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 143423,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMRSZ2102519'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6YG2PNDqV4qfKcKRhyMPKU'},
#    'href': 'https://api.spotify.com/v1/tracks/6YG2PNDqV4qfKcKRhyMPKU',
#    'id': '6YG2PNDqV4qfKcKRhyMPKU',
#    'is_local': False,
#    'name': 'Lose My Number',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2328f5fea69bbeb6e228da07bef31414b0397783?cid=07d38296a179477cb2c5422a972d33de',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6YG2PNDqV4qfKcKRhyMPKU'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7blXVKBSxdFZsIqlhdViKc'},
#       'href': 'https://api.spotify.com/v1/artists/7blXVKBSxdFZsIqlhdViKc',
#       'id': '7blXVKBSxdFZsIqlhdViKc',
#       'name': 'Valley',
#       'type': 'artist',
#       'uri': 'spotify:artist:7blXVKBSxdFZsIqlhdViKc'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3RJi4CGEm5KVAdPxl2fWWa'},
#     'href': 'https://api.spotify.com/v1/albums/3RJi4CGEm5KVAdPxl2fWWa',
#     'id': '3RJi4CGEm5KVAdPxl2fWWa',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273634e1fb57aea679660033b25',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02634e1fb57aea679660033b25',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851634e1fb57aea679660033b25',
#       'width': 64}],
#     'name': 'The After Party',
#     'release_date': '2022-01-12',
#     'release_date_precision': 'day',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:3RJi4CGEm5KVAdPxl2fWWa'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7blXVKBSxdFZsIqlhdViKc'},
#      'href': 'https://api.spotify.com/v1/artists/7blXVKBSxdFZsIqlhdViKc',
#      'id': '7blXVKBSxdFZsIqlhdViKc',
#      'name': 'Valley',
#      'type': 'artist',
#      'uri': 'spotify:artist:7blXVKBSxdFZsIqlhdViKc'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 245998,
#    'explicit': True,
#    'external_ids': {'isrc': 'CAUM72100367'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/491W4t6qtEvd1MupR9r3Zm'},
#    'href': 'https://api.spotify.com/v1/tracks/491W4t6qtEvd1MupR9r3Zm',
#    'id': '491W4t6qtEvd1MupR9r3Zm',
#    'is_local': False,
#    'name': 'Paper Cup (sorry for myself)',
#    'popularity': 50,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e1cfcac55de69add18899cfb038e489351a2bda3?cid=07d38296a179477cb2c5422a972d33de',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:491W4t6qtEvd1MupR9r3Zm'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6kZ42qRrzov54LcAk4onW9'},
#     'href': 'https://api.spotify.com/v1/albums/6kZ42qRrzov54LcAk4onW9',
#     'id': '6kZ42qRrzov54LcAk4onW9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273318443aab3531a0558e79a4d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02318443aab3531a0558e79a4d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851318443aab3531a0558e79a4d',
#       'width': 64}],
#     'name': "Red (Taylor's Version)",
#     'release_date': '2021-11-12',
#     'release_date_precision': 'day',
#     'total_tracks': 30,
#     'type': 'album',
#     'uri': 'spotify:album:6kZ42qRrzov54LcAk4onW9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 223333,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12103678'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4pNApnaUWAL2J4KO2eqokq'},
#    'href': 'https://api.spotify.com/v1/tracks/4pNApnaUWAL2J4KO2eqokq',
#    'id': '4pNApnaUWAL2J4KO2eqokq',
#    'is_local': False,
#    'name': "Come Back...Be Here (Taylor's Version)",
#    'popularity': 74,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0fe02fbb9e91462a15e9ead951138b6bf0dd5460?cid=07d38296a179477cb2c5422a972d33de',
#    'track_number': 18,
#    'type': 'track',
#    'uri': 'spotify:track:4pNApnaUWAL2J4KO2eqokq'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4VdV2qRAYBLINR6uU72V1J'},
#       'href': 'https://api.spotify.com/v1/artists/4VdV2qRAYBLINR6uU72V1J',
#       'id': '4VdV2qRAYBLINR6uU72V1J',
#       'name': 'Joshua Bassett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VdV2qRAYBLINR6uU72V1J'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/62JmTTk0wLV4Y5XB5yFIt0'},
#     'href': 'https://api.spotify.com/v1/albums/62JmTTk0wLV4Y5XB5yFIt0',
#     'id': '62JmTTk0wLV4Y5XB5yFIt0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273aaccdce1c6038f45b7827039',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02aaccdce1c6038f45b7827039',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851aaccdce1c6038f45b7827039',
#       'width': 64}],
#     'name': 'Crisis / Secret / Set Me Free',
#     'release_date': '2021-12-03',
#     'release_date_precision': 'day',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:62JmTTk0wLV4Y5XB5yFIt0'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4VdV2qRAYBLINR6uU72V1J'},
#      'href': 'https://api.spotify.com/v1/artists/4VdV2qRAYBLINR6uU72V1J',
#      'id': '4VdV2qRAYBLINR6uU72V1J',
#      'name': 'Joshua Bassett',
#      'type': 'artist',
#      'uri': 'spotify:artist:4VdV2qRAYBLINR6uU72V1J'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 189093,
#    'explicit': True,
#    'external_ids': {'isrc': 'USWB12104879'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1mEM6KkVMwpuAuqusCMD6m'},
#    'href': 'https://api.spotify.com/v1/tracks/1mEM6KkVMwpuAuqusCMD6m',
#    'id': '1mEM6KkVMwpuAuqusCMD6m',
#    'is_local': False,
#    'name': 'Crisis',
#    'popularity': 73,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d064fa1b5b1710fc9c17241c84eedf757bf1094a?cid=07d38296a179477cb2c5422a972d33de',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1mEM6KkVMwpuAuqusCMD6m'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7oPftvlwr6VrsViSDV7fJY'},
#       'href': 'https://api.spotify.com/v1/artists/7oPftvlwr6VrsViSDV7fJY',
#       'id': '7oPftvlwr6VrsViSDV7fJY',
#       'name': 'Green Day',
#       'type': 'artist',
#       'uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7ij8wQxCAexZiXZbMOHcxE'},
#     'href': 'https://api.spotify.com/v1/albums/7ij8wQxCAexZiXZbMOHcxE',
#     'id': '7ij8wQxCAexZiXZbMOHcxE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e334a0ec724ca498e8c08330',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e334a0ec724ca498e8c08330',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e334a0ec724ca498e8c08330',
#       'width': 64}],
#     'name': 'Father of All...',
#     'release_date': '2020-02-07',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:7ij8wQxCAexZiXZbMOHcxE'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7oPftvlwr6VrsViSDV7fJY'},
#      'href': 'https://api.spotify.com/v1/artists/7oPftvlwr6VrsViSDV7fJY',
#      'id': '7oPftvlwr6VrsViSDV7fJY',
#      'name': 'Green Day',
#      'type': 'artist',
#      'uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 159607,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRE11900384'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3YCUPKddcFr4s6iL4mj6Xy'},
#    'href': 'https://api.spotify.com/v1/tracks/3YCUPKddcFr4s6iL4mj6Xy',
#    'id': '3YCUPKddcFr4s6iL4mj6Xy',
#    'is_local': False,
#    'name': 'Meet Me on the Roof',
#    'popularity': 50,
#    'preview_url': 'https://p.scdn.co/mp3-preview/77a1d5d0c3c5db70a63bbb6c20d20cf41be29591?cid=07d38296a179477cb2c5422a972d33de',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:3YCUPKddcFr4s6iL4mj6Xy'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Hsdzj7Dlq2I7tHP7501T4'},
#       'href': 'https://api.spotify.com/v1/artists/1Hsdzj7Dlq2I7tHP7501T4',
#       'id': '1Hsdzj7Dlq2I7tHP7501T4',
#       'name': 'Niall Horan',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Hsdzj7Dlq2I7tHP7501T4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5gdoRB1AUsGnScCuZ8gmPp'},
#     'href': 'https://api.spotify.com/v1/albums/5gdoRB1AUsGnScCuZ8gmPp',
#     'id': '5gdoRB1AUsGnScCuZ8gmPp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733d13e91ce05c4e9b3e7201b7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023d13e91ce05c4e9b3e7201b7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513d13e91ce05c4e9b3e7201b7',
#       'width': 64}],
#     'name': 'Heartbreak Weather',
#     'release_date': '2020-03-13',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:5gdoRB1AUsGnScCuZ8gmPp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Hsdzj7Dlq2I7tHP7501T4'},
#      'href': 'https://api.spotify.com/v1/artists/1Hsdzj7Dlq2I7tHP7501T4',
#      'id': '1Hsdzj7Dlq2I7tHP7501T4',
#      'name': 'Niall Horan',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Hsdzj7Dlq2I7tHP7501T4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 251883,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12000236'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4Zwt0IkpzDOW2u0YfV94TK'},
#    'href': 'https://api.spotify.com/v1/tracks/4Zwt0IkpzDOW2u0YfV94TK',
#    'id': '4Zwt0IkpzDOW2u0YfV94TK',
#    'is_local': False,
#    'name': 'Still',
#    'popularity': 66,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d339e8b61491af52e07de473507f2d6f68fb17b1?cid=07d38296a179477cb2c5422a972d33de',
#    'track_number': 14,
#    'type': 'track',
#    'uri': 'spotify:track:4Zwt0IkpzDOW2u0YfV94TK'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6kZ42qRrzov54LcAk4onW9'},
#     'href': 'https://api.spotify.com/v1/albums/6kZ42qRrzov54LcAk4onW9',
#     'id': '6kZ42qRrzov54LcAk4onW9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273318443aab3531a0558e79a4d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02318443aab3531a0558e79a4d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851318443aab3531a0558e79a4d',
#       'width': 64}],
#     'name': "Red (Taylor's Version)",
#     'release_date': '2021-11-12',
#     'release_date_precision': 'day',
#     'total_tracks': 30,
#     'type': 'album',
#     'uri': 'spotify:album:6kZ42qRrzov54LcAk4onW9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 295413,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12103661'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6lzc0Al0zfZOIFsFvBS1ki'},
#    'href': 'https://api.spotify.com/v1/tracks/6lzc0Al0zfZOIFsFvBS1ki',
#    'id': '6lzc0Al0zfZOIFsFvBS1ki',
#    'is_local': False,
#    'name': "State Of Grace (Taylor's Version)",
#    'popularity': 77,
#    'preview_url': 'https://p.scdn.co/mp3-preview/200debecab4e5e3a2eb9e64f5bb680c86e31bc11?cid=07d38296a179477cb2c5422a972d33de',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6lzc0Al0zfZOIFsFvBS1ki'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qDMrpZHtZEtVl5i1l7hP3'},
#       'href': 'https://api.spotify.com/v1/artists/3qDMrpZHtZEtVl5i1l7hP3',
#       'id': '3qDMrpZHtZEtVl5i1l7hP3',
#       'name': 'Nightly',
#       'type': 'artist',
#       'uri': 'spotify:artist:3qDMrpZHtZEtVl5i1l7hP3'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2RzQznPCFWvnq3wBh0zzD2'},
#       'href': 'https://api.spotify.com/v1/artists/2RzQznPCFWvnq3wBh0zzD2',
#       'id': '2RzQznPCFWvnq3wBh0zzD2',
#       'name': 'Charli Adams',
#       'type': 'artist',
#       'uri': 'spotify:artist:2RzQznPCFWvnq3wBh0zzD2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7zmo9jWL7G4xj6oSLXRq0v'},
#     'href': 'https://api.spotify.com/v1/albums/7zmo9jWL7G4xj6oSLXRq0v',
#     'id': '7zmo9jWL7G4xj6oSLXRq0v',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273928e44d5e12b7a861a5387d7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02928e44d5e12b7a861a5387d7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851928e44d5e12b7a861a5387d7',
#       'width': 64}],
#     'name': 'the movies (feat. Charli Adams)',
#     'release_date': '2020-04-24',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7zmo9jWL7G4xj6oSLXRq0v'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qDMrpZHtZEtVl5i1l7hP3'},
#      'href': 'https://api.spotify.com/v1/artists/3qDMrpZHtZEtVl5i1l7hP3',
#      'id': '3qDMrpZHtZEtVl5i1l7hP3',
#      'name': 'Nightly',
#      'type': 'artist',
#      'uri': 'spotify:artist:3qDMrpZHtZEtVl5i1l7hP3'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2RzQznPCFWvnq3wBh0zzD2'},
#      'href': 'https://api.spotify.com/v1/artists/2RzQznPCFWvnq3wBh0zzD2',
#      'id': '2RzQznPCFWvnq3wBh0zzD2',
#      'name': 'Charli Adams',
#      'type': 'artist',
#      'uri': 'spotify:artist:2RzQznPCFWvnq3wBh0zzD2'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 178909,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMRSZ2000724'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4rEAtHXza0kdANkTLUwXM1'},
#    'href': 'https://api.spotify.com/v1/tracks/4rEAtHXza0kdANkTLUwXM1',
#    'id': '4rEAtHXza0kdANkTLUwXM1',
#    'is_local': False,
#    'name': 'the movies (feat. Charli Adams)',
#    'popularity': 48,
#    'preview_url': 'https://p.scdn.co/mp3-preview/414f0a0d9236a82810fab776e97cc940a0cb7330?cid=07d38296a179477cb2c5422a972d33de',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4rEAtHXza0kdANkTLUwXM1'}],
#  'total': 50,
#  'limit': 10,
#  'offset': 0,
#  'previous': None,
#  'href': 'https://api.spotify.com/v1/me/top/tracks?limit=10&offset=0&time_range=short_term',
#  'next': 'https://api.spotify.com/v1/me/top/tracks?limit=10&offset=10&time_range=short_term'}

# %%
top_tracks_short = sp.current_user_top_tracks(limit=20, offset=0, time_range = 'short_term')

# %%
type(top_tracks_short)
# Out:
# dict

# %%
#start with empty track_ids list
#for song in dictionary, first go to key 'items'
#then get id for that song
#append to track_ids
def get_track_ids(time_frame):
    track_ids=[]
    for song in time_frame['items']:
        track_ids.append(song['id'])
    return track_ids

# %%
track_ids = get_track_ids(top_tracks_short)

# %%
track_ids
# Out:
# ['697MdxMbVWn1Ajbw8iaPv5',
#  '7q0ez7c8f92Rwpl6nVw5M6',
#  '6YG2PNDqV4qfKcKRhyMPKU',
#  '491W4t6qtEvd1MupR9r3Zm',
#  '4pNApnaUWAL2J4KO2eqokq',
#  '1mEM6KkVMwpuAuqusCMD6m',
#  '3YCUPKddcFr4s6iL4mj6Xy',
#  '4Zwt0IkpzDOW2u0YfV94TK',
#  '6lzc0Al0zfZOIFsFvBS1ki',
#  '4rEAtHXza0kdANkTLUwXM1',
#  '5VgUkdoUGNGdUQQGAJieZe',
#  '7A2cNLRT0YJc1yjxHlKihs',
#  '0DMVrlMUn01M0IcpDbwgu7',
#  '4BIuY0oEopXizyP3WvkNrT',
#  '0v4z1tuZvn6LGknom9Qx7d',
#  '5JMLYOvdtPdSRwJbAPszTr',
#  '5mblHLGgEz6O8WNsv5Z406',
#  '6nfqlFOMiWthaOEa53uU0v',
#  '6cVnHJlv4wVKF7MOTOcHZ6',
#  '25gacl0dFF9HTclx7Ug7xC']

# %%
#pick a song
track_id = '697MdxMbVWn1Ajbw8iaPv5'

# %%
meta = sp.track(track_id)
meta
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7blXVKBSxdFZsIqlhdViKc'},
#     'href': 'https://api.spotify.com/v1/artists/7blXVKBSxdFZsIqlhdViKc',
#     'id': '7blXVKBSxdFZsIqlhdViKc',
#     'name': 'Valley',
#     'type': 'artist',
#     'uri': 'spotify:artist:7blXVKBSxdFZsIqlhdViKc'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3RJi4CGEm5KVAdPxl2fWWa'},
#   'href': 'https://api.spotify.com/v1/albums/3RJi4CGEm5KVAdPxl2fWWa',
#   'id': '3RJi4CGEm5KVAdPxl2fWWa',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273634e1fb57aea679660033b25',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02634e1fb57aea679660033b25',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851634e1fb57aea679660033b25',
#     'width': 64}],
#   'name': 'The After Party',
#   'release_date': '2022-01-12',
#   'release_date_precision': 'day',
#   'total_tracks': 3,
#   'type': 'album',
#   'uri': 'spotify:album:3RJi4CGEm5KVAdPxl2fWWa'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7blXVKBSxdFZsIqlhdViKc'},
#    'href': 'https://api.spotify.com/v1/artists/7blXVKBSxdFZsIqlhdViKc',
#    'id': '7blXVKBSxdFZsIqlhdViKc',
#    'name': 'Valley',
#    'type': 'artist',
#    'uri': 'spotify:artist:7blXVKBSxdFZsIqlhdViKc'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IQ',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'LY',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RU',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TJ',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VE',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 1,
#  'duration_ms': 237230,
#  'explicit': True,
#  'external_ids': {'isrc': 'CAUM72100439'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/697MdxMbVWn1Ajbw8iaPv5'},
#  'href': 'https://api.spotify.com/v1/tracks/697MdxMbVWn1Ajbw8iaPv5',
#  'id': '697MdxMbVWn1Ajbw8iaPv5',
#  'is_local': False,
#  'name': 'Last Birthday',
#  'popularity': 60,
#  'preview_url': 'https://p.scdn.co/mp3-preview/2e5c1d6dfb844d9823c5efb5f2ed32d56d621343?cid=07d38296a179477cb2c5422a972d33de',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:697MdxMbVWn1Ajbw8iaPv5'}

# %%
#create a function to get track features
def get_track_features(id):
    meta=sp.track(id)
    #meta
    name = meta['name']
    album = meta['album']['name']
    artist = meta['album']['artists'][0]['name']
    spotify_url = meta['external_urls']['spotify']
    album_cover = meta['album']['images'][0]['url']
    track_info= [name, album, artist, spotify_url, album_cover]
    return track_info

# %%
get_track_features(track_id)
# Out:
# ['Last Birthday',
#  'The After Party',
#  'Valley',
#  'https://open.spotify.com/track/697MdxMbVWn1Ajbw8iaPv5',
#  'https://i.scdn.co/image/ab67616d0000b273634e1fb57aea679660033b25']

# %%
#loop over track ids to get df of all tracks
#time.sleep(.5) means sleep in between each track
tracks = []
for i in range (len(track_ids)):
    time.sleep(.5)
    track= get_track_features(track_ids[i])
    tracks.append(track)

# %%
tracks
# Out:
# [['Last Birthday',
#   'The After Party',
#   'Valley',
#   'https://open.spotify.com/track/697MdxMbVWn1Ajbw8iaPv5',
#   'https://i.scdn.co/image/ab67616d0000b273634e1fb57aea679660033b25'],
#  ['7 Stories',
#   'The After Party',
#   'Valley',
#   'https://open.spotify.com/track/7q0ez7c8f92Rwpl6nVw5M6',
#   'https://i.scdn.co/image/ab67616d0000b273634e1fb57aea679660033b25'],
#  ['Lose My Number',
#   'Lose My Number',
#   'Nightly',
#   'https://open.spotify.com/track/6YG2PNDqV4qfKcKRhyMPKU',
#   'https://i.scdn.co/image/ab67616d0000b273f3fa268c33fa25670adf4e78'],
#  ['Paper Cup (sorry for myself)',
#   'The After Party',
#   'Valley',
#   'https://open.spotify.com/track/491W4t6qtEvd1MupR9r3Zm',
#   'https://i.scdn.co/image/ab67616d0000b273634e1fb57aea679660033b25'],
#  ["Come Back...Be Here (Taylor's Version)",
#   "Red (Taylor's Version)",
#   'Taylor Swift',
#   'https://open.spotify.com/track/4pNApnaUWAL2J4KO2eqokq',
#   'https://i.scdn.co/image/ab67616d0000b273318443aab3531a0558e79a4d'],
#  ['Crisis',
#   'Crisis / Secret / Set Me Free',
#   'Joshua Bassett',
#   'https://open.spotify.com/track/1mEM6KkVMwpuAuqusCMD6m',
#   'https://i.scdn.co/image/ab67616d0000b273aaccdce1c6038f45b7827039'],
#  ['Meet Me on the Roof',
#   'Father of All...',
#   'Green Day',
#   'https://open.spotify.com/track/3YCUPKddcFr4s6iL4mj6Xy',
#   'https://i.scdn.co/image/ab67616d0000b273e334a0ec724ca498e8c08330'],
#  ['Still',
#   'Heartbreak Weather',
#   'Niall Horan',
#   'https://open.spotify.com/track/4Zwt0IkpzDOW2u0YfV94TK',
#   'https://i.scdn.co/image/ab67616d0000b2733d13e91ce05c4e9b3e7201b7'],
#  ["State Of Grace (Taylor's Version)",
#   "Red (Taylor's Version)",
#   'Taylor Swift',
#   'https://open.spotify.com/track/6lzc0Al0zfZOIFsFvBS1ki',
#   'https://i.scdn.co/image/ab67616d0000b273318443aab3531a0558e79a4d'],
#  ['the movies (feat. Charli Adams)',
#   'the movies (feat. Charli Adams)',
#   'Nightly',
#   'https://open.spotify.com/track/4rEAtHXza0kdANkTLUwXM1',
#   'https://i.scdn.co/image/ab67616d0000b273928e44d5e12b7a861a5387d7'],
#  ['Sticks and Stones (feat. Charlotte Sands)',
#   'Mind Games',
#   'JORDY',
#   'https://open.spotify.com/track/5VgUkdoUGNGdUQQGAJieZe',
#   'https://i.scdn.co/image/ab67616d0000b2732b561094737dd206a8371fc0'],
#  ["Starlight (Taylor's Version)",
#   "Red (Taylor's Version)",
#   'Taylor Swift',
#   'https://open.spotify.com/track/7A2cNLRT0YJc1yjxHlKihs',
#   'https://i.scdn.co/image/ab67616d0000b273318443aab3531a0558e79a4d'],
#  ["Girl At Home (Taylor's Version)",
#   "Red (Taylor's Version)",
#   'Taylor Swift',
#   'https://open.spotify.com/track/0DMVrlMUn01M0IcpDbwgu7',
#   'https://i.scdn.co/image/ab67616d0000b273318443aab3531a0558e79a4d'],
#  ['Oh shit…are we in love?',
#   'Last Birthday',
#   'Valley',
#   'https://open.spotify.com/track/4BIuY0oEopXizyP3WvkNrT',
#   'https://i.scdn.co/image/ab67616d0000b273e661c05b66f93ae82583cafa'],
#  ["Babe (Taylor's Version) (From The Vault)",
#   "Red (Taylor's Version)",
#   'Taylor Swift',
#   'https://open.spotify.com/track/0v4z1tuZvn6LGknom9Qx7d',
#   'https://i.scdn.co/image/ab67616d0000b273318443aab3531a0558e79a4d'],
#  ['Holding On',
#   'The Sound Of Your Voice',
#   'Nightly',
#   'https://open.spotify.com/track/5JMLYOvdtPdSRwJbAPszTr',
#   'https://i.scdn.co/image/ab67616d0000b2733bee6c0555080fcb9f6cd391'],
#  ['Tempo',
#   'Last Birthday',
#   'Valley',
#   'https://open.spotify.com/track/5mblHLGgEz6O8WNsv5Z406',
#   'https://i.scdn.co/image/ab67616d0000b273e661c05b66f93ae82583cafa'],
#  ['Fallin’ (Adrenaline)',
#   'The Good Times and The Bad Ones',
#   "Why Don't We",
#   'https://open.spotify.com/track/6nfqlFOMiWthaOEa53uU0v',
#   'https://i.scdn.co/image/ab67616d0000b273a59fe305e5504a51fa413d29'],
#  ['Can We Make It? (Jim Carrey)',
#   'Last Birthday',
#   'Valley',
#   'https://open.spotify.com/track/6cVnHJlv4wVKF7MOTOcHZ6',
#   'https://i.scdn.co/image/ab67616d0000b273e661c05b66f93ae82583cafa'],
#  ['Like 1999',
#   'Last Birthday',
#   'Valley',
#   'https://open.spotify.com/track/25gacl0dFF9HTclx7Ug7xC',
#   'https://i.scdn.co/image/ab67616d0000b273e661c05b66f93ae82583cafa']]

# %%
#create Df
df= pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'spotify_url', 'album_cover'])
df.head()
# Out:
#                                      name                   album  \
# 0                           Last Birthday         The After Party
# 1                               7 Stories         The After Party
# 2                          Lose My Number          Lose My Number
# 3            Paper Cup (sorry for myself)         The After Party
# 4  Come Back...Be Here (Taylor's Version)  Red (Taylor's Version)
#
#          artist                                        spotify_url  \
# 0        Valley  https://open.spotify.com/track/697MdxMbVWn1Ajb...
# 1        Valley  https://open.spotify.com/track/7q0ez7c8f92Rwpl...
# 2       Nightly  https://open.spotify.com/track/6YG2PNDqV4qfKcK...
# 3        Valley  https://open.spotify.com/track/491W4t6qtEvd1Mu...
# 4  Taylor Swift  https://open.spotify.com/track/4pNApnaUWAL2J4K...
#
#                                          album_cover
# 0  https://i.scdn.co/image/ab67616d0000b273634e1f...
# 1  https://i.scdn.co/image/ab67616d0000b273634e1f...
# 2  https://i.scdn.co/image/ab67616d0000b273f3fa26...
# 3  https://i.scdn.co/image/ab67616d0000b273634e1f...
# 4  https://i.scdn.co/image/ab67616d0000b273318443...

# %%
audio_features = sp.audio_features('697MdxMbVWn1Ajbw8iaPv5')

# %%
type(audio_features)
# Out:
# list

# %%
#create a function to get track features
def get_audio_features(id):
    meta_audio=sp.audio_features(id)
    #meta
    for track in meta_audio: 
        danceability = meta_audio[0]
        energy = meta_audio[0]
        valence = meta_audio[0]
        tempo = meta_audio[0]
        track_audio_info= [danceability, energy, valence, tempo]
    return track_audio_info

# %%
get_audio_features(track_id)
# Out:
# [{'danceability': 0.706,
#   'energy': 0.644,
#   'key': 8,
#   'loudness': -7.772,
#   'mode': 1,
#   'speechiness': 0.0318,
#   'acousticness': 0.14,
#   'instrumentalness': 0,
#   'liveness': 0.154,
#   'valence': 0.603,
#   'tempo': 120.002,
#   'type': 'audio_features',
#   'id': '697MdxMbVWn1Ajbw8iaPv5',
#   'uri': 'spotify:track:697MdxMbVWn1Ajbw8iaPv5',
#   'track_href': 'https://api.spotify.com/v1/tracks/697MdxMbVWn1Ajbw8iaPv5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/697MdxMbVWn1Ajbw8iaPv5',
#   'duration_ms': 237231,
#   'time_signature': 4},
#  {'danceability': 0.706,
#   'energy': 0.644,
#   'key': 8,
#   'loudness': -7.772,
#   'mode': 1,
#   'speechiness': 0.0318,
#   'acousticness': 0.14,
#   'instrumentalness': 0,
#   'liveness': 0.154,
#   'valence': 0.603,
#   'tempo': 120.002,
#   'type': 'audio_features',
#   'id': '697MdxMbVWn1Ajbw8iaPv5',
#   'uri': 'spotify:track:697MdxMbVWn1Ajbw8iaPv5',
#   'track_href': 'https://api.spotify.com/v1/tracks/697MdxMbVWn1Ajbw8iaPv5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/697MdxMbVWn1Ajbw8iaPv5',
#   'duration_ms': 237231,
#   'time_signature': 4},
#  {'danceability': 0.706,
#   'energy': 0.644,
#   'key': 8,
#   'loudness': -7.772,
#   'mode': 1,
#   'speechiness': 0.0318,
#   'acousticness': 0.14,
#   'instrumentalness': 0,
#   'liveness': 0.154,
#   'valence': 0.603,
#   'tempo': 120.002,
#   'type': 'audio_features',
#   'id': '697MdxMbVWn1Ajbw8iaPv5',
#   'uri': 'spotify:track:697MdxMbVWn1Ajbw8iaPv5',
#   'track_href': 'https://api.spotify.com/v1/tracks/697MdxMbVWn1Ajbw8iaPv5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/697MdxMbVWn1Ajbw8iaPv5',
#   'duration_ms': 237231,
#   'time_signature': 4},
#  {'danceability': 0.706,
#   'energy': 0.644,
#   'key': 8,
#   'loudness': -7.772,
#   'mode': 1,
#   'speechiness': 0.0318,
#   'acousticness': 0.14,
#   'instrumentalness': 0,
#   'liveness': 0.154,
#   'valence': 0.603,
#   'tempo': 120.002,
#   'type': 'audio_features',
#   'id': '697MdxMbVWn1Ajbw8iaPv5',
#   'uri': 'spotify:track:697MdxMbVWn1Ajbw8iaPv5',
#   'track_href': 'https://api.spotify.com/v1/tracks/697MdxMbVWn1Ajbw8iaPv5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/697MdxMbVWn1Ajbw8iaPv5',
#   'duration_ms': 237231,
#   'time_signature': 4}]
